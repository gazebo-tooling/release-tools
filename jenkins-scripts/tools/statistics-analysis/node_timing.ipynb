# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import matplotlib.dates as mdates
plt.style.use('ggplot')
sns.set(font_scale=1.2)
sns.set_style("whitegrid")

def load_data(file_path):
    columns = ['timestamp', 'node_name', 'status', 'labels', 'current_job']
    df = pd.read_csv(file_path, names=columns, header=0)
    df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S')
    df['current_job'] = df['current_job'].replace('None', np.nan)
    # Replace the labels using the logic: if docker and gpu-reliable exists in labels use linux-gpu
    def apply_label_rules(labels):
        if 'docker' in labels and 'gpu-reliable' in labels:
            return 'linux-gpu'
        elif 'docker' in labels and 'gpu-reliable' not in labels:
            return 'linux'
        elif 'win' in labels and 'gpu-reliable' in labels:
            return 'windows-gpu'
        elif 'win' in labels and 'gpu-reliable' not in labels:
            return 'windows'        
        elif 'osx' in labels:
            for label in labels.split(', '):
                if label.startswith('osx_'):
                    return label
        elif 'linux-arm64' in labels:
            return 'linux-arm64'          
        else:
            return labels

    df['labels'] = df['labels'].apply(apply_label_rules)     
    return df

def calculate_node_stats(df):
    nodes = df['node_name'].unique()
    node_stats = {}
    
    for node in nodes:
        node_df = df[df['node_name'] == node].sort_values('timestamp')
        first_seen = node_df['timestamp'].min()
        last_seen = node_df['timestamp'].max()
        time_alive = (last_seen - first_seen).total_seconds() / 60
        
        busy_records = node_df[node_df['status'] == 'Busy']
        busy_periods = []
        if not busy_records.empty:
            node_df['status_changed'] = node_df['status'] != node_df['status'].shift(1)
            status_changes = node_df[node_df['status_changed']].copy()
            last_records = node_df.groupby('status').last().reset_index()
            status_change_points = pd.concat([status_changes, last_records]).sort_values('timestamp')
            
            current_status = None
            start_time = None
            
            for _, row in status_change_points.iterrows():
                if current_status == 'Busy' and start_time is not None:
                    duration = (row['timestamp'] - start_time).total_seconds() / 60
                    busy_periods.append({
                        'start': start_time,
                        'end': row['timestamp'],
                        'duration': duration,
                        'job': row['current_job']
                    })
                
                current_status = row['status']
                start_time = row['timestamp']
        
        total_busy_time = sum(period['duration'] for period in busy_periods)
        busy_percentage = (total_busy_time / time_alive * 100) if time_alive > 0 else 0
        
        node_stats[node] = {
            'first_seen': first_seen,
            'last_seen': last_seen,
            'time_alive': time_alive,
            'busy_time': total_busy_time,
            'idle_time': time_alive - total_busy_time,
            'busy_percentage': busy_percentage,
            'busy_periods': busy_periods,
            'status_history': node_df[['timestamp', 'status', 'current_job']].to_dict('records'),
            'labels': node_df['labels'].iloc[0]
        }
    
    return node_stats

def generate_node_report(node_stats):
    sorted_nodes = sorted(node_stats.items(), key=lambda x: x[1]['busy_percentage'], reverse=True)
    report_data = []
    for node, stats in sorted_nodes:
        report_data.append({
            'Node Name': node,
            'Time Alive (min)': round(stats['time_alive'], 2),
            'Busy Time (min)': round(stats['busy_time'], 2),
            'Idle Time (min)': round(stats['idle_time'], 2),
            'Busy (%)': round(stats['busy_percentage'], 2),
            'First Seen': stats['first_seen'],
            'Last Seen': stats['last_seen'],
            'Number of Jobs': len(stats['busy_periods']),
            'Labels': stats['labels']
        })
    
    report_df = pd.DataFrame(report_data)
    return report_df

def analyze_jenkins_nodes(df, title='Jenkins Nodes Activity'):
    node_stats = calculate_node_stats(df)
    report = generate_node_report(node_stats)
    display(report.style.set_caption(title).set_table_styles(
        [{'selector': 'thead th', 'props': [('background-color', '#f7f7f9'), ('color', '#333'), ('border', '1px solid #ddd')]},
         {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#f9f9f9')]},
         {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#fff')]},
         {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('color', '#000')]}]
    ).set_properties(**{'text-align': 'center'}))
    
    print("Node Activity Report:")
    print("===================")
    print(report)
    

    
    return df, node_stats, report


df = load_data("agent_data.csv")
# Absolute
df, node_stats, report = analyze_jenkins_nodes(df)
# filter data to show only workdays
df_workdays = df[df['timestamp'].dt.dayofweek < 5]
df_workdays, node_stats, report = analyze_jenkins_nodes(df_workdays, title='Jenkins Nodes Activity (Workdays)')
# filter data to show only weekends
df_weekends = df[df['timestamp'].dt.dayofweek >= 5]
df_weekends, node_stats, report = analyze_jenkins_nodes(df_weekends, title='Jenkins Nodes Activity (Weekends)')
# Out:
# <style type="text/css">
# #T_c0dcd thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_c0dcd tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_c0dcd tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_c0dcd tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_c0dcd_row0_col0, #T_c0dcd_row0_col1, #T_c0dcd_row0_col2, #T_c0dcd_row0_col3, #T_c0dcd_row0_col4, #T_c0dcd_row0_col5, #T_c0dcd_row0_col6, #T_c0dcd_row0_col7, #T_c0dcd_row0_col8, #T_c0dcd_row1_col0, #T_c0dcd_row1_col1, #T_c0dcd_row1_col2, #T_c0dcd_row1_col3, #T_c0dcd_row1_col4, #T_c0dcd_row1_col5, #T_c0dcd_row1_col6, #T_c0dcd_row1_col7, #T_c0dcd_row1_col8, #T_c0dcd_row2_col0, #T_c0dcd_row2_col1, #T_c0dcd_row2_col2, #T_c0dcd_row2_col3, #T_c0dcd_row2_col4, #T_c0dcd_row2_col5, #T_c0dcd_row2_col6, #T_c0dcd_row2_col7, #T_c0dcd_row2_col8, #T_c0dcd_row3_col0, #T_c0dcd_row3_col1, #T_c0dcd_row3_col2, #T_c0dcd_row3_col3, #T_c0dcd_row3_col4, #T_c0dcd_row3_col5, #T_c0dcd_row3_col6, #T_c0dcd_row3_col7, #T_c0dcd_row3_col8, #T_c0dcd_row4_col0, #T_c0dcd_row4_col1, #T_c0dcd_row4_col2, #T_c0dcd_row4_col3, #T_c0dcd_row4_col4, #T_c0dcd_row4_col5, #T_c0dcd_row4_col6, #T_c0dcd_row4_col7, #T_c0dcd_row4_col8, #T_c0dcd_row5_col0, #T_c0dcd_row5_col1, #T_c0dcd_row5_col2, #T_c0dcd_row5_col3, #T_c0dcd_row5_col4, #T_c0dcd_row5_col5, #T_c0dcd_row5_col6, #T_c0dcd_row5_col7, #T_c0dcd_row5_col8, #T_c0dcd_row6_col0, #T_c0dcd_row6_col1, #T_c0dcd_row6_col2, #T_c0dcd_row6_col3, #T_c0dcd_row6_col4, #T_c0dcd_row6_col5, #T_c0dcd_row6_col6, #T_c0dcd_row6_col7, #T_c0dcd_row6_col8, #T_c0dcd_row7_col0, #T_c0dcd_row7_col1, #T_c0dcd_row7_col2, #T_c0dcd_row7_col3, #T_c0dcd_row7_col4, #T_c0dcd_row7_col5, #T_c0dcd_row7_col6, #T_c0dcd_row7_col7, #T_c0dcd_row7_col8, #T_c0dcd_row8_col0, #T_c0dcd_row8_col1, #T_c0dcd_row8_col2, #T_c0dcd_row8_col3, #T_c0dcd_row8_col4, #T_c0dcd_row8_col5, #T_c0dcd_row8_col6, #T_c0dcd_row8_col7, #T_c0dcd_row8_col8, #T_c0dcd_row9_col0, #T_c0dcd_row9_col1, #T_c0dcd_row9_col2, #T_c0dcd_row9_col3, #T_c0dcd_row9_col4, #T_c0dcd_row9_col5, #T_c0dcd_row9_col6, #T_c0dcd_row9_col7, #T_c0dcd_row9_col8, #T_c0dcd_row10_col0, #T_c0dcd_row10_col1, #T_c0dcd_row10_col2, #T_c0dcd_row10_col3, #T_c0dcd_row10_col4, #T_c0dcd_row10_col5, #T_c0dcd_row10_col6, #T_c0dcd_row10_col7, #T_c0dcd_row10_col8, #T_c0dcd_row11_col0, #T_c0dcd_row11_col1, #T_c0dcd_row11_col2, #T_c0dcd_row11_col3, #T_c0dcd_row11_col4, #T_c0dcd_row11_col5, #T_c0dcd_row11_col6, #T_c0dcd_row11_col7, #T_c0dcd_row11_col8, #T_c0dcd_row12_col0, #T_c0dcd_row12_col1, #T_c0dcd_row12_col2, #T_c0dcd_row12_col3, #T_c0dcd_row12_col4, #T_c0dcd_row12_col5, #T_c0dcd_row12_col6, #T_c0dcd_row12_col7, #T_c0dcd_row12_col8, #T_c0dcd_row13_col0, #T_c0dcd_row13_col1, #T_c0dcd_row13_col2, #T_c0dcd_row13_col3, #T_c0dcd_row13_col4, #T_c0dcd_row13_col5, #T_c0dcd_row13_col6, #T_c0dcd_row13_col7, #T_c0dcd_row13_col8, #T_c0dcd_row14_col0, #T_c0dcd_row14_col1, #T_c0dcd_row14_col2, #T_c0dcd_row14_col3, #T_c0dcd_row14_col4, #T_c0dcd_row14_col5, #T_c0dcd_row14_col6, #T_c0dcd_row14_col7, #T_c0dcd_row14_col8, #T_c0dcd_row15_col0, #T_c0dcd_row15_col1, #T_c0dcd_row15_col2, #T_c0dcd_row15_col3, #T_c0dcd_row15_col4, #T_c0dcd_row15_col5, #T_c0dcd_row15_col6, #T_c0dcd_row15_col7, #T_c0dcd_row15_col8, #T_c0dcd_row16_col0, #T_c0dcd_row16_col1, #T_c0dcd_row16_col2, #T_c0dcd_row16_col3, #T_c0dcd_row16_col4, #T_c0dcd_row16_col5, #T_c0dcd_row16_col6, #T_c0dcd_row16_col7, #T_c0dcd_row16_col8, #T_c0dcd_row17_col0, #T_c0dcd_row17_col1, #T_c0dcd_row17_col2, #T_c0dcd_row17_col3, #T_c0dcd_row17_col4, #T_c0dcd_row17_col5, #T_c0dcd_row17_col6, #T_c0dcd_row17_col7, #T_c0dcd_row17_col8, #T_c0dcd_row18_col0, #T_c0dcd_row18_col1, #T_c0dcd_row18_col2, #T_c0dcd_row18_col3, #T_c0dcd_row18_col4, #T_c0dcd_row18_col5, #T_c0dcd_row18_col6, #T_c0dcd_row18_col7, #T_c0dcd_row18_col8, #T_c0dcd_row19_col0, #T_c0dcd_row19_col1, #T_c0dcd_row19_col2, #T_c0dcd_row19_col3, #T_c0dcd_row19_col4, #T_c0dcd_row19_col5, #T_c0dcd_row19_col6, #T_c0dcd_row19_col7, #T_c0dcd_row19_col8, #T_c0dcd_row20_col0, #T_c0dcd_row20_col1, #T_c0dcd_row20_col2, #T_c0dcd_row20_col3, #T_c0dcd_row20_col4, #T_c0dcd_row20_col5, #T_c0dcd_row20_col6, #T_c0dcd_row20_col7, #T_c0dcd_row20_col8, #T_c0dcd_row21_col0, #T_c0dcd_row21_col1, #T_c0dcd_row21_col2, #T_c0dcd_row21_col3, #T_c0dcd_row21_col4, #T_c0dcd_row21_c ...
#   text-align: center;
# }
# </style>
# <table id="T_c0dcd">
#   <caption>Jenkins Nodes Activity</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0dcd_level0_col0" class="col_heading level0 col0" >Node Name</th>
#       <th id="T_c0dcd_level0_col1" class="col_heading level0 col1" >Time Alive (min)</th>
#       <th id="T_c0dcd_level0_col2" class="col_heading level0 col2" >Busy Time (min)</th>
#       <th id="T_c0dcd_level0_col3" class="col_heading level0 col3" >Idle Time (min)</th>
#       <th id="T_c0dcd_level0_col4" class="col_heading level0 col4" >Busy (%)</th>
#       <th id="T_c0dcd_level0_col5" class="col_heading level0 col5" >First Seen</th>
#       <th id="T_c0dcd_level0_col6" class="col_heading level0 col6" >Last Seen</th>
#       <th id="T_c0dcd_level0_col7" class="col_heading level0 col7" >Number of Jobs</th>
#       <th id="T_c0dcd_level0_col8" class="col_heading level0 col8" >Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0dcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0dcd_row0_col0" class="data row0 col0" >linux-ec2.nv.focal-3865fe66</td>
#       <td id="T_c0dcd_row0_col1" class="data row0 col1" >104.830000</td>
#       <td id="T_c0dcd_row0_col2" class="data row0 col2" >104.830000</td>
#       <td id="T_c0dcd_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_c0dcd_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_c0dcd_row0_col5" class="data row0 col5" >2025-03-14 17:50:10</td>
#       <td id="T_c0dcd_row0_col6" class="data row0 col6" >2025-03-14 19:35:00</td>
#       <td id="T_c0dcd_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_c0dcd_row0_col8" class="data row0 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_c0dcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0dcd_row1_col0" class="data row1 col0" >linux-ec2.nv.focal-be0e29be</td>
#       <td id="T_c0dcd_row1_col1" class="data row1 col1" >725.000000</td>
#       <td id="T_c0dcd_row1_col2" class="data row1 col2" >565.570000</td>
#       <td id="T_c0dcd_row1_col3" class="data row1 col3" >159.430000</td>
#       <td id="T_c0dcd_row1_col4" class="data row1 col4" >78.010000</td>
#       <td id="T_c0dcd_row1_col5" class="data row1 col5" >2025-03-14 05:35:01</td>
#       <td id="T_c0dcd_row1_col6" class="data row1 col6" >2025-03-14 17:40:01</td>
#       <td id="T_c0dcd_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_c0dcd_row1_col8" class="data row1 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_c0dcd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0dcd_row2_col0" class="data row2 col0" >linux-ec2.nv.focal-5ae870bd</td>
#       <td id="T_c0dcd_row2_col1" class="data row2 col1" >1715.000000</td>
#       <td id="T_c0dcd_row2_col2" class="data row2 col2" >1125.100000</td>
#       <td id="T_c0dcd_row2_col3" class="data row2 col3" >589.900000</td>
#       <td id="T_c0dcd_row2_col4" class="data row2 col4" >65.600000</td>
#       <td id="T_c0dcd_row2_col5" class="data row2 col5" >2025-03-13 00:45:00</t
# Node Activity Report:
# ===================
#                                Node Name  Time Alive (min)  Busy Time (min)  \
# 0            linux-ec2.nv.focal-3865fe66            104.83           104.83
# 1            linux-ec2.nv.focal-be0e29be            725.00           565.57
# 2            linux-ec2.nv.focal-5ae870bd           1715.00          1125.10
# 3            linux-ec2.nv.focal-cbfb18c1           1940.17          1197.33
# 4            linux-ec2.nv.focal-e2106c45           3805.02          2144.07
# 5             win-ec2.nv.WinS22-c738539f           6729.98          1783.07
# 6    linux-ip-172-30-1-34.focal-3bd74cfe             99.98            26.22
# 7            linux-ec2.nv.focal-28173d4a            344.97            70.02
# 8    linux-ip-172-30-1-34.focal-78f9f008             64.98            10.00
# 9                      mac-eight.ventura           6729.98           792.43
# 10                       mac-five.sonoma           6729.98           711.35
# 11                       mac-six.ventura           6729.98           679.43
# 12   linux-ip-172-30-1-34.focal-cb0d5d3d           2314.98           214.98
# 13            win-ec2.nv.WinS22-5a866937           6729.98           615.57
# 14                      mac-four.ventura           6729.98           559.67
# 15   linux-ip-172-30-1-34.focal-4afb7717            775.02            53.90
# 16   linux-ip-172-30-1-34.focal-a1c847a0           3580.00           248.47
# 17           linux-ec2.nv.focal-190ed121            144.98            10.00
# 18   linux-ip-172-30-1-34.focal-9a33ab4b           1615.02           111.23
# 19   linux-ip-172-30-1-34.focal-bf09b343           2955.00           202.47
# 20   linux-ip-172-30-1-34.focal-8e335171            770.02            42.53
# 21   linux-ip-172-30-1-34.focal-12a7a400             99.98             5.02
# 22           linux-ec2.nv.focal-9a86ddd2           4630.02            75.08
# 23                core-packages-dfe10fd3           6729.98            24.95
# 24  linux-ip-172-30-1-203.focal-1dbfb471           6729.98             0.00
#
#     Idle Time (min)  Busy (%)          First Seen           Last Seen  \
# 0              0.00    100.00 2025-03-14 17:50:10 2025-03-14 19:35:00
# 1            159.43     78.01 2025-03-14 05:35:01 2025-03-14 17:40:01
# 2            589.90     65.60 2025-03-13 00:45:00 2025-03-14 05:20:00
# 3            742.83     61.71 2025-03-12 21:30:02 2025-03-14 05:50:12
# 4           1660.95     56.35 2025-03-14 19:40:00 2025-03-17 11:05:01
# 5           4946.92     26.49 2025-03-12 18:55:02 2025-03-17 11:05:01
# 6             73.77     26.22 2025-03-12 18:55:02 2025-03-12 20:35:01
# 7            274.95     20.30 2025-03-12 18:55:02 2025-03-13 00:40:00
# 8             54.98     15.39 2025-03-13 19:10:01 2025-03-13 20:15:00
# 9           5937.55     11.77 2025-03-12 18:55:02 2025-03-17 11:05:01
# 10          6018.63     10.57 2025-03-12 18:55:02 2025-03-17 11:05:01
# 11          6050.55     10.10 2025-03-12 18:55:02 2025-03-17 11:05:01
# 12          2100.00      9.29 2025-03-13 19:10:01 2025-03-15 09:45:00
# 13          6114.42      9.15 2025-03-12 18:55:02 2025-03-17 11:05:01
# 14          6170.32      8.32 2025-03-12 18:55:02 2025-03-17 11:05:01
# 15           721.12      6.95 2025-03-12 20:40:01 2025-03-13 09:35:02
# 16          3331.53      6.94 2025-03-14 23:25:01 2025-03-17 11:05:01
# 17           134.98      6.90 2025-03-12 18:55:02 2025-03-12 21:20:01
# 18          1503.78      6.89 2025-03-13 20:25:00 2025-03-14 23:20:01
# 19          2752.53      6.85 2025-03-15 09:50:01 2025-03-17 11:05:01
# 20           727.48      5.52 2025-03-12 20:45:01 2025-03-13 09:35:02
# 21            94.97      5.02 2025-03-12 18:55:02 2025-03-12 20:35:01
# 22          4554.93      1.62 2025-03-14 05:55:00 2025-03-17 11:05:01
# 23          6705.03      0.37 2025-03-12 18:55:02 2025-03-17 11:05:01
# 24          6729.98      0.00 2025-03-12 18:55:02 2025-03-17 11:05:01
#
#     Number of Jobs                                   Labels
# 0                1                                linux-gpu
# 1                4                                linux-gpu
# 2               13                                linux-gpu
# 3               25                                linux-gpu
# 4               34                                linux-gpu
# 5               52                              windows-gpu
# 6                2                                    linux
# 7                5                                linux-gpu
# 8                2                                    linux
# 9               78                              osx_ventura
# 10              69                               osx_sonoma
# 11              79                              osx_ventura
# 12              24                                    linux
# 13              38                                  windows
# 14              65                              osx_ventura
# 15              11                                    linux
# 16              35                                    linux
# 17               3                                linux-gpu
# 18              15                                    linux
# 19              33                                    linux
# 20              10                                    linux
# 21               2                                    linux
# 22               4                                linux-gpu
# 23               6  core-packages-dfe10fd3, packages, swarm
# 24               0                              linux-arm64
# <style type="text/css">
# #T_6a69b thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_6a69b tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_6a69b tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_6a69b tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_6a69b_row0_col0, #T_6a69b_row0_col1, #T_6a69b_row0_col2, #T_6a69b_row0_col3, #T_6a69b_row0_col4, #T_6a69b_row0_col5, #T_6a69b_row0_col6, #T_6a69b_row0_col7, #T_6a69b_row0_col8, #T_6a69b_row1_col0, #T_6a69b_row1_col1, #T_6a69b_row1_col2, #T_6a69b_row1_col3, #T_6a69b_row1_col4, #T_6a69b_row1_col5, #T_6a69b_row1_col6, #T_6a69b_row1_col7, #T_6a69b_row1_col8, #T_6a69b_row2_col0, #T_6a69b_row2_col1, #T_6a69b_row2_col2, #T_6a69b_row2_col3, #T_6a69b_row2_col4, #T_6a69b_row2_col5, #T_6a69b_row2_col6, #T_6a69b_row2_col7, #T_6a69b_row2_col8, #T_6a69b_row3_col0, #T_6a69b_row3_col1, #T_6a69b_row3_col2, #T_6a69b_row3_col3, #T_6a69b_row3_col4, #T_6a69b_row3_col5, #T_6a69b_row3_col6, #T_6a69b_row3_col7, #T_6a69b_row3_col8, #T_6a69b_row4_col0, #T_6a69b_row4_col1, #T_6a69b_row4_col2, #T_6a69b_row4_col3, #T_6a69b_row4_col4, #T_6a69b_row4_col5, #T_6a69b_row4_col6, #T_6a69b_row4_col7, #T_6a69b_row4_col8, #T_6a69b_row5_col0, #T_6a69b_row5_col1, #T_6a69b_row5_col2, #T_6a69b_row5_col3, #T_6a69b_row5_col4, #T_6a69b_row5_col5, #T_6a69b_row5_col6, #T_6a69b_row5_col7, #T_6a69b_row5_col8, #T_6a69b_row6_col0, #T_6a69b_row6_col1, #T_6a69b_row6_col2, #T_6a69b_row6_col3, #T_6a69b_row6_col4, #T_6a69b_row6_col5, #T_6a69b_row6_col6, #T_6a69b_row6_col7, #T_6a69b_row6_col8, #T_6a69b_row7_col0, #T_6a69b_row7_col1, #T_6a69b_row7_col2, #T_6a69b_row7_col3, #T_6a69b_row7_col4, #T_6a69b_row7_col5, #T_6a69b_row7_col6, #T_6a69b_row7_col7, #T_6a69b_row7_col8, #T_6a69b_row8_col0, #T_6a69b_row8_col1, #T_6a69b_row8_col2, #T_6a69b_row8_col3, #T_6a69b_row8_col4, #T_6a69b_row8_col5, #T_6a69b_row8_col6, #T_6a69b_row8_col7, #T_6a69b_row8_col8, #T_6a69b_row9_col0, #T_6a69b_row9_col1, #T_6a69b_row9_col2, #T_6a69b_row9_col3, #T_6a69b_row9_col4, #T_6a69b_row9_col5, #T_6a69b_row9_col6, #T_6a69b_row9_col7, #T_6a69b_row9_col8, #T_6a69b_row10_col0, #T_6a69b_row10_col1, #T_6a69b_row10_col2, #T_6a69b_row10_col3, #T_6a69b_row10_col4, #T_6a69b_row10_col5, #T_6a69b_row10_col6, #T_6a69b_row10_col7, #T_6a69b_row10_col8, #T_6a69b_row11_col0, #T_6a69b_row11_col1, #T_6a69b_row11_col2, #T_6a69b_row11_col3, #T_6a69b_row11_col4, #T_6a69b_row11_col5, #T_6a69b_row11_col6, #T_6a69b_row11_col7, #T_6a69b_row11_col8, #T_6a69b_row12_col0, #T_6a69b_row12_col1, #T_6a69b_row12_col2, #T_6a69b_row12_col3, #T_6a69b_row12_col4, #T_6a69b_row12_col5, #T_6a69b_row12_col6, #T_6a69b_row12_col7, #T_6a69b_row12_col8, #T_6a69b_row13_col0, #T_6a69b_row13_col1, #T_6a69b_row13_col2, #T_6a69b_row13_col3, #T_6a69b_row13_col4, #T_6a69b_row13_col5, #T_6a69b_row13_col6, #T_6a69b_row13_col7, #T_6a69b_row13_col8, #T_6a69b_row14_col0, #T_6a69b_row14_col1, #T_6a69b_row14_col2, #T_6a69b_row14_col3, #T_6a69b_row14_col4, #T_6a69b_row14_col5, #T_6a69b_row14_col6, #T_6a69b_row14_col7, #T_6a69b_row14_col8, #T_6a69b_row15_col0, #T_6a69b_row15_col1, #T_6a69b_row15_col2, #T_6a69b_row15_col3, #T_6a69b_row15_col4, #T_6a69b_row15_col5, #T_6a69b_row15_col6, #T_6a69b_row15_col7, #T_6a69b_row15_col8, #T_6a69b_row16_col0, #T_6a69b_row16_col1, #T_6a69b_row16_col2, #T_6a69b_row16_col3, #T_6a69b_row16_col4, #T_6a69b_row16_col5, #T_6a69b_row16_col6, #T_6a69b_row16_col7, #T_6a69b_row16_col8, #T_6a69b_row17_col0, #T_6a69b_row17_col1, #T_6a69b_row17_col2, #T_6a69b_row17_col3, #T_6a69b_row17_col4, #T_6a69b_row17_col5, #T_6a69b_row17_col6, #T_6a69b_row17_col7, #T_6a69b_row17_col8, #T_6a69b_row18_col0, #T_6a69b_row18_col1, #T_6a69b_row18_col2, #T_6a69b_row18_col3, #T_6a69b_row18_col4, #T_6a69b_row18_col5, #T_6a69b_row18_col6, #T_6a69b_row18_col7, #T_6a69b_row18_col8, #T_6a69b_row19_col0, #T_6a69b_row19_col1, #T_6a69b_row19_col2, #T_6a69b_row19_col3, #T_6a69b_row19_col4, #T_6a69b_row19_col5, #T_6a69b_row19_col6, #T_6a69b_row19_col7, #T_6a69b_row19_col8, #T_6a69b_row20_col0, #T_6a69b_row20_col1, #T_6a69b_row20_col2, #T_6a69b_row20_col3, #T_6a69b_row20_col4, #T_6a69b_row20_col5, #T_6a69b_row20_col6, #T_6a69b_row20_col7, #T_6a69b_row20_col8, #T_6a69b_row21_col0, #T_6a69b_row21_col1, #T_6a69b_row21_col2, #T_6a69b_row21_col3, #T_6a69b_row21_col4, #T_6a69b_row21_c ...
#   text-align: center;
# }
# </style>
# <table id="T_6a69b">
#   <caption>Jenkins Nodes Activity (Workdays)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a69b_level0_col0" class="col_heading level0 col0" >Node Name</th>
#       <th id="T_6a69b_level0_col1" class="col_heading level0 col1" >Time Alive (min)</th>
#       <th id="T_6a69b_level0_col2" class="col_heading level0 col2" >Busy Time (min)</th>
#       <th id="T_6a69b_level0_col3" class="col_heading level0 col3" >Idle Time (min)</th>
#       <th id="T_6a69b_level0_col4" class="col_heading level0 col4" >Busy (%)</th>
#       <th id="T_6a69b_level0_col5" class="col_heading level0 col5" >First Seen</th>
#       <th id="T_6a69b_level0_col6" class="col_heading level0 col6" >Last Seen</th>
#       <th id="T_6a69b_level0_col7" class="col_heading level0 col7" >Number of Jobs</th>
#       <th id="T_6a69b_level0_col8" class="col_heading level0 col8" >Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a69b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a69b_row0_col0" class="data row0 col0" >linux-ec2.nv.focal-3865fe66</td>
#       <td id="T_6a69b_row0_col1" class="data row0 col1" >104.830000</td>
#       <td id="T_6a69b_row0_col2" class="data row0 col2" >104.830000</td>
#       <td id="T_6a69b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6a69b_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_6a69b_row0_col5" class="data row0 col5" >2025-03-14 17:50:10</td>
#       <td id="T_6a69b_row0_col6" class="data row0 col6" >2025-03-14 19:35:00</td>
#       <td id="T_6a69b_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_6a69b_row0_col8" class="data row0 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_6a69b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a69b_row1_col0" class="data row1 col0" >linux-ec2.nv.focal-e2106c45</td>
#       <td id="T_6a69b_row1_col1" class="data row1 col1" >3805.020000</td>
#       <td id="T_6a69b_row1_col2" class="data row1 col2" >3409.930000</td>
#       <td id="T_6a69b_row1_col3" class="data row1 col3" >395.080000</td>
#       <td id="T_6a69b_row1_col4" class="data row1 col4" >89.620000</td>
#       <td id="T_6a69b_row1_col5" class="data row1 col5" >2025-03-14 19:40:00</td>
#       <td id="T_6a69b_row1_col6" class="data row1 col6" >2025-03-17 11:05:01</td>
#       <td id="T_6a69b_row1_col7" class="data row1 col7" >11</td>
#       <td id="T_6a69b_row1_col8" class="data row1 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_6a69b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a69b_row2_col0" class="data row2 col0" >linux-ec2.nv.focal-be0e29be</td>
#       <td id="T_6a69b_row2_col1" class="data row2 col1" >725.000000</td>
#       <td id="T_6a69b_row2_col2" class="data row2 col2" >565.570000</td>
#       <td id="T_6a69b_row2_col3" class="data row2 col3" >159.430000</td>
#       <td id="T_6a69b_row2_col4" class="data row2 col4" >78.010000</td>
#       <td id="T_6a69b_row2_col5" class="data row2 col5" >2025-03-14
# Node Activity Report:
# ===================
#                                Node Name  Time Alive (min)  Busy Time (min)  \
# 0            linux-ec2.nv.focal-3865fe66            104.83           104.83
# 1            linux-ec2.nv.focal-e2106c45           3805.02          3409.93
# 2            linux-ec2.nv.focal-be0e29be            725.00           565.57
# 3            linux-ec2.nv.focal-5ae870bd           1715.00          1125.10
# 4            linux-ec2.nv.focal-cbfb18c1           1940.17          1197.33
# 5             win-ec2.nv.WinS22-c738539f           6729.98          4153.27
# 6    linux-ip-172-30-1-34.focal-3bd74cfe             99.98            26.22
# 7            linux-ec2.nv.focal-28173d4a            344.97            70.02
# 8    linux-ip-172-30-1-34.focal-78f9f008             64.98            10.00
# 9    linux-ip-172-30-1-34.focal-cb0d5d3d           1725.00           164.98
# 10                     mac-eight.ventura           6729.98           552.65
# 11   linux-ip-172-30-1-34.focal-bf09b343            665.02            49.95
# 12   linux-ip-172-30-1-34.focal-4afb7717            775.02            53.90
# 13           linux-ec2.nv.focal-190ed121            144.98            10.00
# 14   linux-ip-172-30-1-34.focal-9a33ab4b           1615.02           111.23
# 15            win-ec2.nv.WinS22-5a866937           6729.98           445.28
# 16   linux-ip-172-30-1-34.focal-8e335171            770.02            42.53
# 17                       mac-five.sonoma           6729.98           370.93
# 18                       mac-six.ventura           6729.98           355.00
# 19   linux-ip-172-30-1-34.focal-12a7a400             99.98             5.02
# 20                      mac-four.ventura           6729.98           291.52
# 21           linux-ec2.nv.focal-9a86ddd2           4630.02            75.08
# 22   linux-ip-172-30-1-34.focal-a1c847a0           3580.00            39.97
# 23                core-packages-dfe10fd3           6729.98             9.98
# 24  linux-ip-172-30-1-203.focal-1dbfb471           6729.98             0.00
#
#     Idle Time (min)  Busy (%)          First Seen           Last Seen  \
# 0              0.00    100.00 2025-03-14 17:50:10 2025-03-14 19:35:00
# 1            395.08     89.62 2025-03-14 19:40:00 2025-03-17 11:05:01
# 2            159.43     78.01 2025-03-14 05:35:01 2025-03-14 17:40:01
# 3            589.90     65.60 2025-03-13 00:45:00 2025-03-14 05:20:00
# 4            742.83     61.71 2025-03-12 21:30:02 2025-03-14 05:50:12
# 5           2576.72     61.71 2025-03-12 18:55:02 2025-03-17 11:05:01
# 6             73.77     26.22 2025-03-12 18:55:02 2025-03-12 20:35:01
# 7            274.95     20.30 2025-03-12 18:55:02 2025-03-13 00:40:00
# 8             54.98     15.39 2025-03-13 19:10:01 2025-03-13 20:15:00
# 9           1560.02      9.56 2025-03-13 19:10:01 2025-03-14 23:55:01
# 10          6177.33      8.21 2025-03-12 18:55:02 2025-03-17 11:05:01
# 11           615.07      7.51 2025-03-17 00:00:00 2025-03-17 11:05:01
# 12           721.12      6.95 2025-03-12 20:40:01 2025-03-13 09:35:02
# 13           134.98      6.90 2025-03-12 18:55:02 2025-03-12 21:20:01
# 14          1503.78      6.89 2025-03-13 20:25:00 2025-03-14 23:20:01
# 15          6284.70      6.62 2025-03-12 18:55:02 2025-03-17 11:05:01
# 16           727.48      5.52 2025-03-12 20:45:01 2025-03-13 09:35:02
# 17          6359.05      5.51 2025-03-12 18:55:02 2025-03-17 11:05:01
# 18          6374.98      5.27 2025-03-12 18:55:02 2025-03-17 11:05:01
# 19            94.97      5.02 2025-03-12 18:55:02 2025-03-12 20:35:01
# 20          6438.47      4.33 2025-03-12 18:55:02 2025-03-17 11:05:01
# 21          4554.93      1.62 2025-03-14 05:55:00 2025-03-17 11:05:01
# 22          3540.03      1.12 2025-03-14 23:25:01 2025-03-17 11:05:01
# 23          6720.00      0.15 2025-03-12 18:55:02 2025-03-17 11:05:01
# 24          6729.98      0.00 2025-03-12 18:55:02 2025-03-17 11:05:01
#
#     Number of Jobs                                   Labels
# 0                1                                linux-gpu
# 1               11                                linux-gpu
# 2                4                                linux-gpu
# 3               13                                linux-gpu
# 4               25                                linux-gpu
# 5               33                              windows-gpu
# 6                2                                    linux
# 7                5                                linux-gpu
# 8                2                                    linux
# 9               22                                    linux
# 10              49                              osx_ventura
# 11              10                                    linux
# 12              11                                    linux
# 13               3                                linux-gpu
# 14              15                                    linux
# 15              26                                  windows
# 16              10                                    linux
# 17              38                               osx_sonoma
# 18              39                              osx_ventura
# 19               2                                    linux
# 20              35                              osx_ventura
# 21               4                                linux-gpu
# 22               8                                    linux
# 23               3  core-packages-dfe10fd3, packages, swarm
# 24               0                              linux-arm64
# <style type="text/css">
# #T_7f93a thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_7f93a tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_7f93a tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_7f93a tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_7f93a_row0_col0, #T_7f93a_row0_col1, #T_7f93a_row0_col2, #T_7f93a_row0_col3, #T_7f93a_row0_col4, #T_7f93a_row0_col5, #T_7f93a_row0_col6, #T_7f93a_row0_col7, #T_7f93a_row0_col8, #T_7f93a_row1_col0, #T_7f93a_row1_col1, #T_7f93a_row1_col2, #T_7f93a_row1_col3, #T_7f93a_row1_col4, #T_7f93a_row1_col5, #T_7f93a_row1_col6, #T_7f93a_row1_col7, #T_7f93a_row1_col8, #T_7f93a_row2_col0, #T_7f93a_row2_col1, #T_7f93a_row2_col2, #T_7f93a_row2_col3, #T_7f93a_row2_col4, #T_7f93a_row2_col5, #T_7f93a_row2_col6, #T_7f93a_row2_col7, #T_7f93a_row2_col8, #T_7f93a_row3_col0, #T_7f93a_row3_col1, #T_7f93a_row3_col2, #T_7f93a_row3_col3, #T_7f93a_row3_col4, #T_7f93a_row3_col5, #T_7f93a_row3_col6, #T_7f93a_row3_col7, #T_7f93a_row3_col8, #T_7f93a_row4_col0, #T_7f93a_row4_col1, #T_7f93a_row4_col2, #T_7f93a_row4_col3, #T_7f93a_row4_col4, #T_7f93a_row4_col5, #T_7f93a_row4_col6, #T_7f93a_row4_col7, #T_7f93a_row4_col8, #T_7f93a_row5_col0, #T_7f93a_row5_col1, #T_7f93a_row5_col2, #T_7f93a_row5_col3, #T_7f93a_row5_col4, #T_7f93a_row5_col5, #T_7f93a_row5_col6, #T_7f93a_row5_col7, #T_7f93a_row5_col8, #T_7f93a_row6_col0, #T_7f93a_row6_col1, #T_7f93a_row6_col2, #T_7f93a_row6_col3, #T_7f93a_row6_col4, #T_7f93a_row6_col5, #T_7f93a_row6_col6, #T_7f93a_row6_col7, #T_7f93a_row6_col8, #T_7f93a_row7_col0, #T_7f93a_row7_col1, #T_7f93a_row7_col2, #T_7f93a_row7_col3, #T_7f93a_row7_col4, #T_7f93a_row7_col5, #T_7f93a_row7_col6, #T_7f93a_row7_col7, #T_7f93a_row7_col8, #T_7f93a_row8_col0, #T_7f93a_row8_col1, #T_7f93a_row8_col2, #T_7f93a_row8_col3, #T_7f93a_row8_col4, #T_7f93a_row8_col5, #T_7f93a_row8_col6, #T_7f93a_row8_col7, #T_7f93a_row8_col8, #T_7f93a_row9_col0, #T_7f93a_row9_col1, #T_7f93a_row9_col2, #T_7f93a_row9_col3, #T_7f93a_row9_col4, #T_7f93a_row9_col5, #T_7f93a_row9_col6, #T_7f93a_row9_col7, #T_7f93a_row9_col8, #T_7f93a_row10_col0, #T_7f93a_row10_col1, #T_7f93a_row10_col2, #T_7f93a_row10_col3, #T_7f93a_row10_col4, #T_7f93a_row10_col5, #T_7f93a_row10_col6, #T_7f93a_row10_col7, #T_7f93a_row10_col8, #T_7f93a_row11_col0, #T_7f93a_row11_col1, #T_7f93a_row11_col2, #T_7f93a_row11_col3, #T_7f93a_row11_col4, #T_7f93a_row11_col5, #T_7f93a_row11_col6, #T_7f93a_row11_col7, #T_7f93a_row11_col8, #T_7f93a_row12_col0, #T_7f93a_row12_col1, #T_7f93a_row12_col2, #T_7f93a_row12_col3, #T_7f93a_row12_col4, #T_7f93a_row12_col5, #T_7f93a_row12_col6, #T_7f93a_row12_col7, #T_7f93a_row12_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_7f93a">
#   <caption>Jenkins Nodes Activity (Weekends)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f93a_level0_col0" class="col_heading level0 col0" >Node Name</th>
#       <th id="T_7f93a_level0_col1" class="col_heading level0 col1" >Time Alive (min)</th>
#       <th id="T_7f93a_level0_col2" class="col_heading level0 col2" >Busy Time (min)</th>
#       <th id="T_7f93a_level0_col3" class="col_heading level0 col3" >Idle Time (min)</th>
#       <th id="T_7f93a_level0_col4" class="col_heading level0 col4" >Busy (%)</th>
#       <th id="T_7f93a_level0_col5" class="col_heading level0 col5" >First Seen</th>
#       <th id="T_7f93a_level0_col6" class="col_heading level0 col6" >Last Seen</th>
#       <th id="T_7f93a_level0_col7" class="col_heading level0 col7" >Number of Jobs</th>
#       <th id="T_7f93a_level0_col8" class="col_heading level0 col8" >Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f93a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f93a_row0_col0" class="data row0 col0" >linux-ec2.nv.focal-e2106c45</td>
#       <td id="T_7f93a_row0_col1" class="data row0 col1" >2871.970000</td>
#       <td id="T_7f93a_row0_col2" class="data row0 col2" >1611.100000</td>
#       <td id="T_7f93a_row0_col3" class="data row0 col3" >1260.870000</td>
#       <td id="T_7f93a_row0_col4" class="data row0 col4" >56.100000</td>
#       <td id="T_7f93a_row0_col5" class="data row0 col5" >2025-03-15 00:03:02</td>
#       <td id="T_7f93a_row0_col6" class="data row0 col6" >2025-03-16 23:55:00</td>
#       <td id="T_7f93a_row0_col7" class="data row0 col7" >25</td>
#       <td id="T_7f93a_row0_col8" class="data row0 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_7f93a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f93a_row1_col0" class="data row1 col0" >win-ec2.nv.WinS22-c738539f</td>
#       <td id="T_7f93a_row1_col1" class="data row1 col1" >2871.970000</td>
#       <td id="T_7f93a_row1_col2" class="data row1 col2" >506.770000</td>
#       <td id="T_7f93a_row1_col3" class="data row1 col3" >2365.200000</td>
#       <td id="T_7f93a_row1_col4" class="data row1 col4" >17.650000</td>
#       <td id="T_7f93a_row1_col5" class="data row1 col5" >2025-03-15 00:03:02</td>
#       <td id="T_7f93a_row1_col6" class="data row1 col6" >2025-03-16 23:55:00</td>
#       <td id="T_7f93a_row1_col7" class="data row1 col7" >21</td>
#       <td id="T_7f93a_row1_col8" class="data row1 col8" >windows-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_7f93a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f93a_row2_col0" class="data row2 col0" >mac-five.sonoma</td>
#       <td id="T_7f93a_row2_col1" class="data row2 col1" >2871.970000</td>
#       <td id="T_7f93a_row2_col2" class="data row2 col2" >340.420000</td>
#       <td id="T_7f93a_row2_col3" class="data row2 col3" >2531.550000</td>
#       <td id="T_7f93a_row2_col4" class="data row2 col4" >11.850000</td>
#       <td id="T_7f93a_row2_col5" class="data row2 col5" >2025-03-15 00:03:02</td>
#       <td id="T_7f93a_row2_col6" class="data row2 col6" >2025-03-16 23:55:00</td>
#       <td id="T_7f93a_row2_col7" class="data row2 col7" >32</td>
#       <td id="T_7f93a_row2_col8" class="data row2 col8" >osx_sonoma</td>
#     </tr>
#     <tr>
#       <th id="T_7f93a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f93a_row3_col0" class="data row3 col0" >mac-six.ventura</td>
#       <td id="T_7f93a_row3_col1" class="data row3 col1" >2871.970000</td>
#       <td id="T_7f93a_row3_col2" class="data row3 col2" >324.430000</td>
#       <td id="T_7f93a_row3_col3" class="data row3 col3" >2547.530000</td>
#       <td id="T_7f93a_row3_col4" class="data row3 col4" >11.300000</td>
#       <td id="T_7f93a_row3_col5" class="data row3 col5" >2025-03-15 00:03:02</td>
#       <td id="T_7f93a_row3_col6" class="data row3 col6" >2025-03-16 23:55:00</td>
#       <td id="T_7f93a_row3_col7" class="data row3 col7" >41</td>
#       <td id="T_7f93a_row3_col8" class="data row3 col8" >osx_ventura</td>
#     </tr>
#     <tr>
#       <th id="T_7f93a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f93a_row4_col0" class="data row4 col0" >mac-four.ventura</td>
#       <td id="T_7f93a_row4_col1" class="data row4 col1" >2871.970000</td>
#       <td id="T_7f93a_row4_col2" class="data row4 col2" >268.150000</td>
#       <td id="T_7f93a_row4_col3" class="data row4 col3" >2603.820000</td>
#       <td id="T_7f93a_row4_col4" class="data row4 col4" >9.340000</td>
#       <td id="T_7f93a_row4_col5" class="data row4 col5" >2025-03-15 00:03:02</td>
#       <td id="T_7f93a_row4_col6" class="data row4 col6" >2025-03-16 23:55:00</td>
#       <td id="T_7f93a_row4_col7" class="data row4 col7" >31</td>
#       <td id="T_7f93a_row4_col8" class="data row4 col8" >osx_ventura</td>
#     </tr>
#     <tr>
#       <th id="T_7f93a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f93a_row5_col0" class="data row5 col0" >linux-ip-172-30-1-34.focal-cb0d5d3d</td>
#       <td id="T_7f93a_row5_col1" class="data row5 col1" >581.970000</td>
#       <td id="T_7f93a_row5_col2" class="data row5 col2" >50.000000</td>
#       <td id="T_7f93a_row5_col3" class="data row5 col3" >531.970000</td>
#       <td id="T_7f93a_row5_col4" class="data row5 col4" >8.590000</td>
#       <td id="T_7f93
# Node Activity Report:
# ===================
#                                Node Name  Time Alive (min)  Busy Time (min)  \
# 0            linux-ec2.nv.focal-e2106c45           2871.97          1611.10
# 1             win-ec2.nv.WinS22-c738539f           2871.97           506.77
# 2                        mac-five.sonoma           2871.97           340.42
# 3                        mac-six.ventura           2871.97           324.43
# 4                       mac-four.ventura           2871.97           268.15
# 5    linux-ip-172-30-1-34.focal-cb0d5d3d            581.97            50.00
# 6                      mac-eight.ventura           2871.97           239.78
# 7    linux-ip-172-30-1-34.focal-a1c847a0           2871.97           208.50
# 8    linux-ip-172-30-1-34.focal-bf09b343           2284.98           152.52
# 9             win-ec2.nv.WinS22-5a866937           2871.97           170.28
# 10                core-packages-dfe10fd3           2871.97            14.97
# 11           linux-ec2.nv.focal-9a86ddd2           2871.97             0.00
# 12  linux-ip-172-30-1-203.focal-1dbfb471           2871.97             0.00
#
#     Idle Time (min)  Busy (%)          First Seen           Last Seen  \
# 0           1260.87     56.10 2025-03-15 00:03:02 2025-03-16 23:55:00
# 1           2365.20     17.65 2025-03-15 00:03:02 2025-03-16 23:55:00
# 2           2531.55     11.85 2025-03-15 00:03:02 2025-03-16 23:55:00
# 3           2547.53     11.30 2025-03-15 00:03:02 2025-03-16 23:55:00
# 4           2603.82      9.34 2025-03-15 00:03:02 2025-03-16 23:55:00
# 5            531.97      8.59 2025-03-15 00:03:02 2025-03-15 09:45:00
# 6           2632.18      8.35 2025-03-15 00:03:02 2025-03-16 23:55:00
# 7           2663.47      7.26 2025-03-15 00:03:02 2025-03-16 23:55:00
# 8           2132.47      6.67 2025-03-15 09:50:01 2025-03-16 23:55:00
# 9           2701.68      5.93 2025-03-15 00:03:02 2025-03-16 23:55:00
# 10          2857.00      0.52 2025-03-15 00:03:02 2025-03-16 23:55:00
# 11          2871.97      0.00 2025-03-15 00:03:02 2025-03-16 23:55:00
# 12          2871.97      0.00 2025-03-15 00:03:02 2025-03-16 23:55:00
#
#     Number of Jobs                                   Labels
# 0               25                                linux-gpu
# 1               21                              windows-gpu
# 2               32                               osx_sonoma
# 3               41                              osx_ventura
# 4               31                              osx_ventura
# 5                3                                    linux
# 6               30                              osx_ventura
# 7               28                                    linux
# 8               24                                    linux
# 9               13                                  windows
# 10               4  core-packages-dfe10fd3, packages, swarm
# 11               0                                linux-gpu
# 12               0                              linux-arm64
