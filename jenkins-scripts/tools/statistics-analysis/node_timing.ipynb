# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import matplotlib.dates as mdates
plt.style.use('ggplot')
sns.set(font_scale=1.2)
sns.set_style("whitegrid")

def load_data(file_path):
    columns = ['timestamp', 'node_name', 'status', 'labels', 'current_job']
    df = pd.read_csv(file_path, names=columns, header=0)
    df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S')
    df['current_job'] = df['current_job'].replace('None', np.nan)
    # Replace the labels using the logic: if docker and gpu-reliable exists in labels use linux-gpu
    def apply_label_rules(labels):
        if 'docker' in labels and 'gpu-reliable' in labels:
            return 'linux-gpu'
        elif 'docker' in labels and 'gpu-reliable' not in labels:
            return 'linux'
        elif 'win' in labels and 'gpu-reliable' in labels:
            return 'windows-gpu'
        elif 'win' in labels and 'gpu-reliable' not in labels:
            return 'windows'        
        elif 'osx' in labels:
            for label in labels.split(', '):
                if label.startswith('osx_'):
                    return label
        elif 'linux-arm64' in labels:
            return 'linux-arm64'          
        else:
            return labels

    df['labels'] = df['labels'].apply(apply_label_rules)     
    return df

def calculate_node_stats(df):
    nodes = df['node_name'].unique()
    node_stats = {}
    
    for node in nodes:
        node_df = df[df['node_name'] == node].sort_values('timestamp')
        first_seen = node_df['timestamp'].min()
        last_seen = node_df['timestamp'].max()
        time_alive = (last_seen - first_seen).total_seconds() / 60
        
        busy_records = node_df[node_df['status'] == 'Busy']
        busy_periods = []
        if not busy_records.empty:
            node_df['status_changed'] = node_df['status'] != node_df['status'].shift(1)
            status_changes = node_df[node_df['status_changed']].copy()
            last_records = node_df.groupby('status').last().reset_index()
            status_change_points = pd.concat([status_changes, last_records]).sort_values('timestamp')
            
            current_status = None
            start_time = None
            
            for _, row in status_change_points.iterrows():
                if current_status == 'Busy' and start_time is not None:
                    duration = (row['timestamp'] - start_time).total_seconds() / 60
                    busy_periods.append({
                        'start': start_time,
                        'end': row['timestamp'],
                        'duration': duration,
                        'job': row['current_job']
                    })
                
                current_status = row['status']
                start_time = row['timestamp']
        
        total_busy_time = sum(period['duration'] for period in busy_periods)
        busy_percentage = (total_busy_time / time_alive * 100) if time_alive > 0 else 0
        
        node_stats[node] = {
            'first_seen': first_seen,
            'last_seen': last_seen,
            'time_alive': time_alive,
            'busy_time': total_busy_time,
            'idle_time': time_alive - total_busy_time,
            'busy_percentage': busy_percentage,
            'busy_periods': busy_periods,
            'status_history': node_df[['timestamp', 'status', 'current_job']].to_dict('records'),
            'labels': node_df['labels'].iloc[0]
        }
    
    return node_stats

def generate_node_report(node_stats):
    sorted_nodes = sorted(node_stats.items(), key=lambda x: x[1]['busy_percentage'], reverse=True)
    report_data = []
    for node, stats in sorted_nodes:
        report_data.append({
            'Node Name': node,
            'Time Alive (min)': round(stats['time_alive'], 2),
            'Busy Time (min)': round(stats['busy_time'], 2),
            'Idle Time (min)': round(stats['idle_time'], 2),
            'Busy (%)': round(stats['busy_percentage'], 2),
            'First Seen': stats['first_seen'],
            'Last Seen': stats['last_seen'],
            'Number of Jobs': len(stats['busy_periods']),
            'Labels': stats['labels']
        })
    
    report_df = pd.DataFrame(report_data)
    return report_df

def analyze_jenkins_nodes(df, title='Jenkins Nodes Activity'):
    node_stats = calculate_node_stats(df)
    report = generate_node_report(node_stats)
    display(report.style.set_caption(title).set_table_styles(
        [{'selector': 'thead th', 'props': [('background-color', '#f7f7f9'), ('color', '#333'), ('border', '1px solid #ddd')]},
         {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#f9f9f9')]},
         {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#fff')]},
         {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('color', '#000')]}]
    ).set_properties(**{'text-align': 'center'}))
    
    print("Node Activity Report:")
    print("===================")
    print(report)
    

    
    return df, node_stats, report


df = load_data("agent_data.csv")
# Absolute
# df, node_stats, report = analyze_jenkins_nodes(df)
# filter data to show only workdays
df_workdays = df[df['timestamp'].dt.dayofweek < 5]
df_workdays, node_stats_workdays, report = analyze_jenkins_nodes(df_workdays, title='Jenkins Nodes Activity (Workdays)')
# filter data to show only weekends
df_weekends = df[df['timestamp'].dt.dayofweek >= 5]
df_weekends, node_stats_weekends, report = analyze_jenkins_nodes(df_weekends, title='Jenkins Nodes Activity (Weekends)')

# Group by labels and recalculate the busy/idle times proportionally the time alive of each node
def calculate_label_stats(node_stats):
    label_stats = {}
    for node, stats in node_stats.items():
        label = stats['labels']
        if label not in label_stats:
            label_stats[label] = {
                'time_alive': 0,
                'busy_time': 0,
                'idle_time': 0
            }
        
        label_stats[label]['time_alive'] += stats['time_alive']
        label_stats[label]['busy_time'] += stats['busy_time']
        label_stats[label]['idle_time'] += stats['idle_time']
    
    for label, stats in label_stats.items():
        stats['busy_percentage'] = (stats['busy_time'] / stats['time_alive'] * 100) if stats['time_alive'] > 0 else 0
    
    return label_stats

def generate_label_report(node_stats, title='Jenkins Nodes Activity by Labels'):
    label_stats = calculate_label_stats(node_stats)
    label_report = pd.DataFrame(label_stats).T
    label_report = label_report.sort_values('busy_percentage', ascending=False)
    label_report = label_report.rename_axis('Labels').reset_index()
    label_report = label_report[['Labels', 'time_alive', 'busy_time', 'idle_time', 'busy_percentage']]
    display(label_report.style.set_caption(title).set_table_styles(
        [{'selector': 'thead th', 'props': [('background-color', '#f7f7f9'), ('color', '#333'), ('border', '1px solid #ddd')]},
         {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#f9f9f9')]},
         {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#fff')]},
         {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('color', '#000')]}]
    ).set_properties(**{'text-align': 'center'}))
    return label_report

label_report_workdays = generate_label_report(node_stats_wordays, title='Jenkins Nodes Activity by Labels (workdays)')
label_report_weekends = generate_label_report(node_stats_weekends, title='Jenkins Nodes Activity by Labels (weekends)')
# Out:
# <style type="text/css">
# #T_c56e5 thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_c56e5 tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_c56e5 tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_c56e5 tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_c56e5_row0_col0, #T_c56e5_row0_col1, #T_c56e5_row0_col2, #T_c56e5_row0_col3, #T_c56e5_row0_col4, #T_c56e5_row0_col5, #T_c56e5_row0_col6, #T_c56e5_row0_col7, #T_c56e5_row0_col8, #T_c56e5_row1_col0, #T_c56e5_row1_col1, #T_c56e5_row1_col2, #T_c56e5_row1_col3, #T_c56e5_row1_col4, #T_c56e5_row1_col5, #T_c56e5_row1_col6, #T_c56e5_row1_col7, #T_c56e5_row1_col8, #T_c56e5_row2_col0, #T_c56e5_row2_col1, #T_c56e5_row2_col2, #T_c56e5_row2_col3, #T_c56e5_row2_col4, #T_c56e5_row2_col5, #T_c56e5_row2_col6, #T_c56e5_row2_col7, #T_c56e5_row2_col8, #T_c56e5_row3_col0, #T_c56e5_row3_col1, #T_c56e5_row3_col2, #T_c56e5_row3_col3, #T_c56e5_row3_col4, #T_c56e5_row3_col5, #T_c56e5_row3_col6, #T_c56e5_row3_col7, #T_c56e5_row3_col8, #T_c56e5_row4_col0, #T_c56e5_row4_col1, #T_c56e5_row4_col2, #T_c56e5_row4_col3, #T_c56e5_row4_col4, #T_c56e5_row4_col5, #T_c56e5_row4_col6, #T_c56e5_row4_col7, #T_c56e5_row4_col8, #T_c56e5_row5_col0, #T_c56e5_row5_col1, #T_c56e5_row5_col2, #T_c56e5_row5_col3, #T_c56e5_row5_col4, #T_c56e5_row5_col5, #T_c56e5_row5_col6, #T_c56e5_row5_col7, #T_c56e5_row5_col8, #T_c56e5_row6_col0, #T_c56e5_row6_col1, #T_c56e5_row6_col2, #T_c56e5_row6_col3, #T_c56e5_row6_col4, #T_c56e5_row6_col5, #T_c56e5_row6_col6, #T_c56e5_row6_col7, #T_c56e5_row6_col8, #T_c56e5_row7_col0, #T_c56e5_row7_col1, #T_c56e5_row7_col2, #T_c56e5_row7_col3, #T_c56e5_row7_col4, #T_c56e5_row7_col5, #T_c56e5_row7_col6, #T_c56e5_row7_col7, #T_c56e5_row7_col8, #T_c56e5_row8_col0, #T_c56e5_row8_col1, #T_c56e5_row8_col2, #T_c56e5_row8_col3, #T_c56e5_row8_col4, #T_c56e5_row8_col5, #T_c56e5_row8_col6, #T_c56e5_row8_col7, #T_c56e5_row8_col8, #T_c56e5_row9_col0, #T_c56e5_row9_col1, #T_c56e5_row9_col2, #T_c56e5_row9_col3, #T_c56e5_row9_col4, #T_c56e5_row9_col5, #T_c56e5_row9_col6, #T_c56e5_row9_col7, #T_c56e5_row9_col8, #T_c56e5_row10_col0, #T_c56e5_row10_col1, #T_c56e5_row10_col2, #T_c56e5_row10_col3, #T_c56e5_row10_col4, #T_c56e5_row10_col5, #T_c56e5_row10_col6, #T_c56e5_row10_col7, #T_c56e5_row10_col8, #T_c56e5_row11_col0, #T_c56e5_row11_col1, #T_c56e5_row11_col2, #T_c56e5_row11_col3, #T_c56e5_row11_col4, #T_c56e5_row11_col5, #T_c56e5_row11_col6, #T_c56e5_row11_col7, #T_c56e5_row11_col8, #T_c56e5_row12_col0, #T_c56e5_row12_col1, #T_c56e5_row12_col2, #T_c56e5_row12_col3, #T_c56e5_row12_col4, #T_c56e5_row12_col5, #T_c56e5_row12_col6, #T_c56e5_row12_col7, #T_c56e5_row12_col8, #T_c56e5_row13_col0, #T_c56e5_row13_col1, #T_c56e5_row13_col2, #T_c56e5_row13_col3, #T_c56e5_row13_col4, #T_c56e5_row13_col5, #T_c56e5_row13_col6, #T_c56e5_row13_col7, #T_c56e5_row13_col8, #T_c56e5_row14_col0, #T_c56e5_row14_col1, #T_c56e5_row14_col2, #T_c56e5_row14_col3, #T_c56e5_row14_col4, #T_c56e5_row14_col5, #T_c56e5_row14_col6, #T_c56e5_row14_col7, #T_c56e5_row14_col8, #T_c56e5_row15_col0, #T_c56e5_row15_col1, #T_c56e5_row15_col2, #T_c56e5_row15_col3, #T_c56e5_row15_col4, #T_c56e5_row15_col5, #T_c56e5_row15_col6, #T_c56e5_row15_col7, #T_c56e5_row15_col8, #T_c56e5_row16_col0, #T_c56e5_row16_col1, #T_c56e5_row16_col2, #T_c56e5_row16_col3, #T_c56e5_row16_col4, #T_c56e5_row16_col5, #T_c56e5_row16_col6, #T_c56e5_row16_col7, #T_c56e5_row16_col8, #T_c56e5_row17_col0, #T_c56e5_row17_col1, #T_c56e5_row17_col2, #T_c56e5_row17_col3, #T_c56e5_row17_col4, #T_c56e5_row17_col5, #T_c56e5_row17_col6, #T_c56e5_row17_col7, #T_c56e5_row17_col8, #T_c56e5_row18_col0, #T_c56e5_row18_col1, #T_c56e5_row18_col2, #T_c56e5_row18_col3, #T_c56e5_row18_col4, #T_c56e5_row18_col5, #T_c56e5_row18_col6, #T_c56e5_row18_col7, #T_c56e5_row18_col8, #T_c56e5_row19_col0, #T_c56e5_row19_col1, #T_c56e5_row19_col2, #T_c56e5_row19_col3, #T_c56e5_row19_col4, #T_c56e5_row19_col5, #T_c56e5_row19_col6, #T_c56e5_row19_col7, #T_c56e5_row19_col8, #T_c56e5_row20_col0, #T_c56e5_row20_col1, #T_c56e5_row20_col2, #T_c56e5_row20_col3, #T_c56e5_row20_col4, #T_c56e5_row20_col5, #T_c56e5_row20_col6, #T_c56e5_row20_col7, #T_c56e5_row20_col8, #T_c56e5_row21_col0, #T_c56e5_row21_col1, #T_c56e5_row21_col2, #T_c56e5_row21_col3, #T_c56e5_row21_col4, #T_c56e5_row21_c ...
# Node Activity Report:
# ===================
#                                Node Name  Time Alive (min)  Busy Time (min)  \
# 0            linux-ec2.nv.focal-3865fe66            104.83           104.83
# 1            linux-ec2.nv.focal-be0e29be            725.00           565.57
# 2            linux-ec2.nv.focal-e2106c45           7170.03          5073.00
# 3            linux-ec2.nv.focal-5ae870bd           1715.00          1125.10
# 4            linux-ec2.nv.focal-cbfb18c1           1940.17          1197.33
# 5            linux-ec2.nv.focal-96fbd432            340.00           184.92
# 6            linux-ec2.nv.focal-0cffe680           4095.00          2022.07
# 7            linux-ec2.nv.focal-994d8826           1274.78           549.18
# 8             win-ec2.nv.WinS22-c738539f          16969.97          7188.83
# 9    linux-ip-172-30-1-34.focal-3bd74cfe             99.98            26.22
# 10           linux-ec2.nv.focal-28173d4a            344.97            70.02
# 11           linux-ec2.nv.focal-078bcd6c           5575.00           990.97
# 12           linux-ec2.nv.focal-0f3a2a16           5575.00           881.82
# 13   linux-ip-172-30-1-34.focal-5dd9d5be            825.00           129.32
# 14   linux-ip-172-30-1-34.focal-78f9f008             64.98            10.00
# 15   linux-ip-172-30-1-34.focal-ef65bc48           1280.00           145.57
# 16                     mac-eight.ventura          16969.97          1835.72
# 17   linux-ip-172-30-1-34.focal-13bc2e9a            140.43            15.00
# 18   linux-ip-172-30-1-34.focal-4cdc7c4b           1852.10           193.12
# 19   linux-ip-172-30-1-34.focal-c704914d           1425.00           144.20
# 20   linux-ip-172-30-1-34.focal-4720d05d           1214.72           122.72
# 21   linux-ip-172-30-1-34.focal-cb0d5d3d           1725.00           164.98
# 22   linux-ip-172-30-1-34.focal-bf09b343           2590.03           238.52
# 23            win-ec2.nv.WinS22-5a866937          16969.97          1561.95
# 24                       mac-five.sonoma          16969.97          1554.75
# 25                       mac-six.ventura          16969.97          1424.73
# 26   linux-ip-172-30-1-34.focal-f709a6e7             60.00             5.00
# 27   linux-ip-172-30-1-34.focal-675f79df            255.00            20.00
# 28                      mac-four.ventura          16969.97          1237.75
# 29   linux-ip-172-30-1-34.focal-711e3e47            285.00            19.98
# 30   linux-ip-172-30-1-34.focal-4afb7717            775.02            53.90
# 31           linux-ec2.nv.focal-190ed121            144.98            10.00
# 32   linux-ip-172-30-1-34.focal-9a33ab4b           1615.02           111.23
# 33   linux-ip-172-30-1-34.focal-3fee71d2           1305.00            79.32
# 34   linux-ip-172-30-1-34.focal-8e335171            770.02            42.53
# 35   linux-ip-172-30-1-34.focal-d009594a            979.97            52.30
# 36   linux-ip-172-30-1-34.focal-12a7a400             99.98             5.02
# 37   linux-ip-172-30-1-34.focal-a1871786            115.00             5.00
# 38   linux-ip-172-30-1-34.focal-93247462           3980.00           113.47
# 39   linux-ip-172-30-1-34.focal-6bd269d3            740.02            20.93
# 40   linux-ip-172-30-1-34.focal-a1c847a0           4080.00            79.30
# 41   linux-ip-172-30-1-34.focal-2805dcaf            285.00             5.00
# 42           linux-ec2.nv.focal-9a86ddd2           4690.00            75.08
# 43                core-packages-dfe10fd3          16969.97            78.08
# 44  linux-ip-172-30-1-203.focal-1dbfb471          16969.97             0.00
# 45           linux-ec2.nv.focal-c44bd75b            135.00             0.00
# 46   linux-ip-172-30-1-34.focal-572aea25             55.30             0.00
# 47   linux-ip-172-30-1-34.focal-80976620             60.30             0.00
# 48   linux-ip-172-30-1-34.focal-38c2c35c             25.00             0.00
# 49   linux-ip-172-30-1-34.focal-b2d26745             75.00             0.00
# 50   linux-ip-172-30-1-34.focal-c9d1d66e              5.00             0.00
# 51   linux-ip-172-30-1-34.focal-0997b2bf             35.00             0.00
#
#     Idle Time (min)  Busy (%)          First Seen           Last Seen  \
# 0              0.00    100.00 2025-03-14 17:50:10 2025-03-14 19:35:00
# 1            159.43     78.01 2025-03-14 05:35:01 2025-03-14 17:40:01
# 2           2097.03     70.75 2025-03-14 19:40:00 2025-03-19 19:10:02
# 3            589.90     65.60 2025-03-13 00:45:00 2025-03-14 05:20:00
# 4            742.83     61.71 2025-03-12 21:30:02 2025-03-14 05:50:12
# 5            155.08     54.39 2025-03-17 12:10:00 2025-03-17 17:50:00
# 6           2072.93     49.38 2025-03-17 20:25:00 2025-03-20 16:40:00
# 7            725.60     43.08 2025-03-19 19:25:13 2025-03-20 16:40:00
# 8           9781.13     42.36 2025-03-12 18:55:02 2025-03-24 13:45:00
# 9             73.77     26.22 2025-03-12 18:55:02 2025-03-12 20:35:01
# 10           274.95     20.30 2025-03-12 18:55:02 2025-03-13 00:40:00
# 11          4584.03     17.78 2025-03-20 16:50:00 2025-03-24 13:45:00
# 12          4693.18     15.82 2025-03-20 16:50:00 2025-03-24 13:45:00
# 13           695.68     15.67 2025-03-24 00:00:00 2025-03-24 13:45:00
# 14            54.98     15.39 2025-03-13 19:10:01 2025-03-13 20:15:00
# 15          1134.43     11.37 2025-03-19 19:55:00 2025-03-20 17:15:00
# 16         15134.25     10.82 2025-03-12 18:55:02 2025-03-24 13:45:00
# 17           125.43     10.68 2025-03-19 12:55:00 2025-03-19 15:15:26
# 18          1658.98     10.43 2025-03-18 12:55:01 2025-03-19 19:47:07
# 19          1280.80     10.12 2025-03-20 17:15:00 2025-03-21 17:00:00
# 20          1092.00     10.10 2025-03-19 16:30:17 2025-03-20 12:45:00
# 21          1560.02      9.56 2025-03-13 19:10:01 2025-03-14 23:55:01
# 22          2351.52      9.21 2025-03-17 00:00:00 2025-03-18 19:10:02
# 23         15408.02      9.20 2025-03-12 18:55:02 2025-03-24 13:45:00
# 24         15415.22      9.16 2025-03-12 18:55:02 2025-03-24 13:45:00
# 25         15545.23      8.40 2025-03-12 18:55:02 2025-03-24 13:45:00
# 26            55.00      8.33 2025-03-21 18:00:00 2025-03-21 19:00:00
# 27           235.00      7.84 2025-03-20 12:55:00 2025-03-20 17:10:00
# 28         15732.22      7.29 2025-03-12 18:55:02 2025-03-24 13:45:00
# 29           265.02      7.01 2025-03-18 08:00:01 2025-03-18 12:45:01
# 30           721.12      6.95 2025-03-12 20:40:01 2025-03-13 09:35:02
# 31           134.98      6.90 2025-03-12 18:55:02 2025-03-12 21:20:01
# 32          1503.78      6.89 2025-03-13 20:25:00 2025-03-14 23:20:01
# 33          1225.68      6.08 2025-03-20 18:00:00 2025-03-21 15:45:00
# 34           727.48      5.52 2025-03-12 20:45:01 2025-03-13 09:35:02
# 35           927.67      5.34 2025-03-18 20:25:02 2025-03-19 12:45:00
# 36            94.97      5.02 2025-03-12 18:55:02 2025-03-12 20:35:01
# 37           110.00      4.35 2025-03-21 17:20:00 2025-03-21 19:15:00
# 38          3866.53      2.85 2025-03-21 19:25:00 2025-03-24 13:45:00
# 39           719.08      2.83 2025-03-17 19:35:01 2025-03-18 07:55:02
# 40          4000.70      1.94 2025-03-14 23:25:01 2025-03-17 19:25:01
# 41           280.00      1.75 2025-03-21 19:10:00 2025-03-21 23:55:00
# 42          4614.92      1.60 2025-03-14 05:55:00 2025-03-17 12:05:00
# 43         16891.88      0.46 2025-03-12 18:55:02 2025-03-24 13:45:00
# 44         16969.97      0.00 2025-03-12 18:55:02 2025-03-24 13:45:00
# 45           135.00      0.00 2025-03-17 18:00:00 2025-03-17 20:15:00
# 46            55.30      0.00 2025-03-18 19:20:02 2025-03-18 20:15:20
# 47            60.30      0.00 2025-03-19 15:20:00 2025-03-19 16:20:18
# 48            25.00      0.00 2025-03-20 17:25:00 2025-03-20 17:50:00
# 49            75.00      0.00 2025-03-21 15:55:00 2025-03-21 17:10:00
# 50             5.00      0.00 2025-03-21 17:10:00 2025-03-21 17:15:00
# 51            35.00      0.00 2025-03-21 17:20:00 2025-03-21 17:55:00
#
#     Number of Jobs                                   Labels
# 0                1                                linux-gpu
# 1                4                                linux-gpu
# 2               45                                linux-gpu
# 3               13                                linux-gpu
# 4               25                                linux-gpu
# 5                3                                linux-gpu
# 6               59                                linux-gpu
# 7               24                                linux-gpu
# 8              112                              windows-gpu
# 9                2                                    linux
# 10               5                                linux-gpu
# 11              30                                linux-gpu
# 12              30                                linux-gpu
# 13              15                                    linux
# 14               2                                    linux
# 15              23                                    linux
# 16             156                              osx_ventura
# 17               4                                    linux
# 18              20                                    linux
# 19              18                                    linux
# 20              18                                    linux
# 21              22                                    linux
# 22              32                                    linux
# 23              95                                  windows
# 24             141                               osx_sonoma
# 25             159                              osx_ventura
# 26               2                                    linux
# 27               5                                    linux
# 28             123                              osx_ventura
# 29               3                                    linux
# 30              11                                    linux
# 31               3                                linux-gpu
# 32              15                                    linux
# 33              13                                    linux
# 34              10                                    linux
# 35               7                                    linux
# 36               2                                    linux
# 37               2                                    linux
# 38              17                                    linux
# 39               5                                    linux
# 40              13                                    linux
# 41               2                                    linux
# 42               4                                linux-gpu
# 43              16  core-packages-dfe10fd3, packages, swarm
# 44               0                              linux-arm64
# 45               0                                linux-gpu
# 46               0                                    linux
# 47               0                                    linux
# 48               0                                    linux
# 49               1                                    linux
# 50               0                                    linux
# 51               0                                    linux
# <style type="text/css">
# #T_16d90 thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_16d90 tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_16d90 tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_16d90 tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_16d90_row0_col0, #T_16d90_row0_col1, #T_16d90_row0_col2, #T_16d90_row0_col3, #T_16d90_row0_col4, #T_16d90_row0_col5, #T_16d90_row0_col6, #T_16d90_row0_col7, #T_16d90_row0_col8, #T_16d90_row1_col0, #T_16d90_row1_col1, #T_16d90_row1_col2, #T_16d90_row1_col3, #T_16d90_row1_col4, #T_16d90_row1_col5, #T_16d90_row1_col6, #T_16d90_row1_col7, #T_16d90_row1_col8, #T_16d90_row2_col0, #T_16d90_row2_col1, #T_16d90_row2_col2, #T_16d90_row2_col3, #T_16d90_row2_col4, #T_16d90_row2_col5, #T_16d90_row2_col6, #T_16d90_row2_col7, #T_16d90_row2_col8, #T_16d90_row3_col0, #T_16d90_row3_col1, #T_16d90_row3_col2, #T_16d90_row3_col3, #T_16d90_row3_col4, #T_16d90_row3_col5, #T_16d90_row3_col6, #T_16d90_row3_col7, #T_16d90_row3_col8, #T_16d90_row4_col0, #T_16d90_row4_col1, #T_16d90_row4_col2, #T_16d90_row4_col3, #T_16d90_row4_col4, #T_16d90_row4_col5, #T_16d90_row4_col6, #T_16d90_row4_col7, #T_16d90_row4_col8, #T_16d90_row5_col0, #T_16d90_row5_col1, #T_16d90_row5_col2, #T_16d90_row5_col3, #T_16d90_row5_col4, #T_16d90_row5_col5, #T_16d90_row5_col6, #T_16d90_row5_col7, #T_16d90_row5_col8, #T_16d90_row6_col0, #T_16d90_row6_col1, #T_16d90_row6_col2, #T_16d90_row6_col3, #T_16d90_row6_col4, #T_16d90_row6_col5, #T_16d90_row6_col6, #T_16d90_row6_col7, #T_16d90_row6_col8, #T_16d90_row7_col0, #T_16d90_row7_col1, #T_16d90_row7_col2, #T_16d90_row7_col3, #T_16d90_row7_col4, #T_16d90_row7_col5, #T_16d90_row7_col6, #T_16d90_row7_col7, #T_16d90_row7_col8, #T_16d90_row8_col0, #T_16d90_row8_col1, #T_16d90_row8_col2, #T_16d90_row8_col3, #T_16d90_row8_col4, #T_16d90_row8_col5, #T_16d90_row8_col6, #T_16d90_row8_col7, #T_16d90_row8_col8, #T_16d90_row9_col0, #T_16d90_row9_col1, #T_16d90_row9_col2, #T_16d90_row9_col3, #T_16d90_row9_col4, #T_16d90_row9_col5, #T_16d90_row9_col6, #T_16d90_row9_col7, #T_16d90_row9_col8, #T_16d90_row10_col0, #T_16d90_row10_col1, #T_16d90_row10_col2, #T_16d90_row10_col3, #T_16d90_row10_col4, #T_16d90_row10_col5, #T_16d90_row10_col6, #T_16d90_row10_col7, #T_16d90_row10_col8, #T_16d90_row11_col0, #T_16d90_row11_col1, #T_16d90_row11_col2, #T_16d90_row11_col3, #T_16d90_row11_col4, #T_16d90_row11_col5, #T_16d90_row11_col6, #T_16d90_row11_col7, #T_16d90_row11_col8, #T_16d90_row12_col0, #T_16d90_row12_col1, #T_16d90_row12_col2, #T_16d90_row12_col3, #T_16d90_row12_col4, #T_16d90_row12_col5, #T_16d90_row12_col6, #T_16d90_row12_col7, #T_16d90_row12_col8, #T_16d90_row13_col0, #T_16d90_row13_col1, #T_16d90_row13_col2, #T_16d90_row13_col3, #T_16d90_row13_col4, #T_16d90_row13_col5, #T_16d90_row13_col6, #T_16d90_row13_col7, #T_16d90_row13_col8, #T_16d90_row14_col0, #T_16d90_row14_col1, #T_16d90_row14_col2, #T_16d90_row14_col3, #T_16d90_row14_col4, #T_16d90_row14_col5, #T_16d90_row14_col6, #T_16d90_row14_col7, #T_16d90_row14_col8, #T_16d90_row15_col0, #T_16d90_row15_col1, #T_16d90_row15_col2, #T_16d90_row15_col3, #T_16d90_row15_col4, #T_16d90_row15_col5, #T_16d90_row15_col6, #T_16d90_row15_col7, #T_16d90_row15_col8, #T_16d90_row16_col0, #T_16d90_row16_col1, #T_16d90_row16_col2, #T_16d90_row16_col3, #T_16d90_row16_col4, #T_16d90_row16_col5, #T_16d90_row16_col6, #T_16d90_row16_col7, #T_16d90_row16_col8, #T_16d90_row17_col0, #T_16d90_row17_col1, #T_16d90_row17_col2, #T_16d90_row17_col3, #T_16d90_row17_col4, #T_16d90_row17_col5, #T_16d90_row17_col6, #T_16d90_row17_col7, #T_16d90_row17_col8, #T_16d90_row18_col0, #T_16d90_row18_col1, #T_16d90_row18_col2, #T_16d90_row18_col3, #T_16d90_row18_col4, #T_16d90_row18_col5, #T_16d90_row18_col6, #T_16d90_row18_col7, #T_16d90_row18_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_16d90">
#   <caption>Jenkins Nodes Activity (Weekends)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16d90_level0_col0" class="col_heading level0 col0" >Node Name</th>
#       <th id="T_16d90_level0_col1" class="col_heading level0 col1" >Time Alive (min)</th>
#       <th id="T_16d90_level0_col2" class="col_heading level0 col2" >Busy Time (min)</th>
#       <th id="T_16d90_level0_col3" class="col_heading level0 col3" >Idle Time (min)</th>
#       <th id="T_16d90_level0_col4" class="col_heading level0 col4" >Busy (%)</th>
#       <th id="T_16d90_level0_col5" class="col_heading level0 col5" >First Seen</th>
#       <th id="T_16d90_level0_col6" class="col_heading level0 col6" >Last Seen</th>
#       <th id="T_16d90_level0_col7" class="col_heading level0 col7" >Number of Jobs</th>
#       <th id="T_16d90_level0_col8" class="col_heading level0 col8" >Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16d90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16d90_row0_col0" class="data row0 col0" >linux-ec2.nv.focal-078bcd6c</td>
#       <td id="T_16d90_row0_col1" class="data row0 col1" >2875.000000</td>
#       <td id="T_16d90_row0_col2" class="data row0 col2" >1935.870000</td>
#       <td id="T_16d90_row0_col3" class="data row0 col3" >939.130000</td>
#       <td id="T_16d90_row0_col4" class="data row0 col4" >67.330000</td>
#       <td id="T_16d90_row0_col5" class="data row0 col5" >2025-03-22 00:00:00</td>
#       <td id="T_16d90_row0_col6" class="data row0 col6" >2025-03-23 23:55:00</td>
#       <td id="T_16d90_row0_col7" class="data row0 col7" >19</td>
#       <td id="T_16d90_row0_col8" class="data row0 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_16d90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16d90_row1_col0" class="data row1 col0" >linux-ec2.nv.focal-e2106c45</td>
#       <td id="T_16d90_row1_col1" class="data row1 col1" >2871.970000</td>
#       <td id="T_16d90_row1_col2" class="data row1 col2" >1611.100000</td>
#       <td id="T_16d90_row1_col3" class="data row1 col3" >1260.870000</td>
#       <td id="T_16d90_row1_col4" class="data row1 col4" >56.100000</td>
#       <td id="T_16d90_row1_col5" class="data row1 col5" >2025-03-15 00:03:02</td>
#       <td id="T_16d90_row1_col6" class="data row1 col6" >2025-03-16 23:55:00</td>
#       <td id="T_16d90_row1_col7" class="data row1 col7" >25</td>
#       <td id="T_16d90_row1_col8" class="data row1 col8" >linux-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_16d90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16d90_row2_col0" class="data row2 col0" >linux-ip-172-30-1-34.focal-2805dcaf</td>
#       <td id="T_16d90_row2_col1" class="data row2 col1" >135.000000</td>
#       <td id="T_16d90_row2_col2" class="data row2 col2" >25.000000</td>
#       <td id="T_16d90_row2_col3" class="data row2 col3" >110.000000</td>
#       <td id="T_16d90_row2_col4" class="data row2 col4" >18.520000</td>
#       <td id="T_16d90_row2_col5" class="data row2 col5" >2025-03-22 00:00:00</td>
#       <td id="T_16d90_row2_col6" class="data row2 col6" >2025-03-22 02:15:00</td>
#       <td id="T_16d90_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_16d90_row2_col8" class="data row2 col8" >linux</td>
#     </tr>
#     <tr>
#       <th id="T_16d90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16d90_row3_col0" class="data row3 col0" >win-ec2.nv.WinS22-c738539f</td>
#       <td id="T_16d90_row3_col1" class="data row3 col1" >12951.970000</td>
#       <td id="T_16d90_row3_col2" class="data row3 col2" >1220.820000</td>
#       <td id="T_16d90_row3_col3" class="data row3 col3" >11731.150000</td>
#       <td id="T_16d90_row3_col4" class="data row3 col4" >9.430000</td>
#       <td id="T_16d90_row3_col5" class="data row3 col5" >2025-03-15 00:03:02</td>
#       <td id="T_16d90_row3_col6" class="data row3 col6" >2025-03-23 23:55:00</td>
#       <td id="T_16d90_row3_col7" class="data row3 col7" >37</td>
#       <td id="T_16d90_row3_col8" class="data row3 col8" >windows-gpu</td>
#     </tr>
#     <tr>
#       <th id="T_16d90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16
# Node Activity Report:
# ===================
#                                Node Name  Time Alive (min)  Busy Time (min)  \
# 0            linux-ec2.nv.focal-078bcd6c           2875.00          1935.87
# 1            linux-ec2.nv.focal-e2106c45           2871.97          1611.10
# 2    linux-ip-172-30-1-34.focal-2805dcaf            135.00            25.00
# 3             win-ec2.nv.WinS22-c738539f          12951.97          1220.82
# 4    linux-ip-172-30-1-34.focal-cb0d5d3d            581.97            50.00
# 5    linux-ip-172-30-1-34.focal-5dd9d5be           2735.00           225.07
# 6    linux-ip-172-30-1-34.focal-a1c847a0           2871.97           208.50
# 7    linux-ip-172-30-1-34.focal-93247462           2875.00           193.30
# 8    linux-ip-172-30-1-34.focal-bf09b343           2284.98           152.52
# 9                        mac-six.ventura          12951.97           750.52
# 10                       mac-five.sonoma          12951.97           695.03
# 11                      mac-four.ventura          12951.97           594.30
# 12                     mac-eight.ventura          12951.97           436.88
# 13            win-ec2.nv.WinS22-5a866937          12951.97           302.12
# 14           linux-ec2.nv.focal-0f3a2a16           2875.00            43.78
# 15                core-packages-dfe10fd3          12951.97            19.72
# 16           linux-ec2.nv.focal-9a86ddd2           2871.97             0.00
# 17  linux-ip-172-30-1-203.focal-1dbfb471          12951.97             0.00
# 18           linux-ec2.nv.focal-ab22092e              0.00             0.00
#
#     Idle Time (min)  Busy (%)          First Seen           Last Seen  \
# 0            939.13     67.33 2025-03-22 00:00:00 2025-03-23 23:55:00
# 1           1260.87     56.10 2025-03-15 00:03:02 2025-03-16 23:55:00
# 2            110.00     18.52 2025-03-22 00:00:00 2025-03-22 02:15:00
# 3          11731.15      9.43 2025-03-15 00:03:02 2025-03-23 23:55:00
# 4            531.97      8.59 2025-03-15 00:03:02 2025-03-15 09:45:00
# 5           2509.93      8.23 2025-03-22 02:20:00 2025-03-23 23:55:00
# 6           2663.47      7.26 2025-03-15 00:03:02 2025-03-16 23:55:00
# 7           2681.70      6.72 2025-03-22 00:00:00 2025-03-23 23:55:00
# 8           2132.47      6.67 2025-03-15 09:50:01 2025-03-16 23:55:00
# 9          12201.45      5.79 2025-03-15 00:03:02 2025-03-23 23:55:00
# 10         12256.93      5.37 2025-03-15 00:03:02 2025-03-23 23:55:00
# 11         12357.67      4.59 2025-03-15 00:03:02 2025-03-23 23:55:00
# 12         12515.08      3.37 2025-03-15 00:03:02 2025-03-23 23:55:00
# 13         12649.85      2.33 2025-03-15 00:03:02 2025-03-23 23:55:00
# 14          2831.22      1.52 2025-03-22 00:00:00 2025-03-23 23:55:00
# 15         12932.25      0.15 2025-03-15 00:03:02 2025-03-23 23:55:00
# 16          2871.97      0.00 2025-03-15 00:03:02 2025-03-16 23:55:00
# 17         12951.97      0.00 2025-03-15 00:03:02 2025-03-23 23:55:00
# 18             0.00      0.00 2025-03-23 19:40:00 2025-03-23 19:40:00
#
#     Number of Jobs                                   Labels
# 0               19                                linux-gpu
# 1               25                                linux-gpu
# 2                5                                    linux
# 3               37                              windows-gpu
# 4                3                                    linux
# 5               32                                    linux
# 6               28                                    linux
# 7               23                                    linux
# 8               24                                    linux
# 9               83                              osx_ventura
# 10              64                               osx_sonoma
# 11              64                              osx_ventura
# 12              51                              osx_ventura
# 13              23                                  windows
# 14               5                                linux-gpu
# 15               5  core-packages-dfe10fd3, packages, swarm
# 16               0                                linux-gpu
# 17               0                              linux-arm64
# 18               0                                linux-gpu
# <style type="text/css">
# #T_c44fa thead th {
#   background-color: #f7f7f9;
#   color: #333;
#   border: 1px solid #ddd;
# }
# #T_c44fa tbody tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_c44fa tbody tr:nth-child(odd) {
#   background-color: #fff;
# }
# #T_c44fa tbody td {
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_c44fa_row0_col0, #T_c44fa_row0_col1, #T_c44fa_row0_col2, #T_c44fa_row0_col3, #T_c44fa_row0_col4, #T_c44fa_row1_col0, #T_c44fa_row1_col1, #T_c44fa_row1_col2, #T_c44fa_row1_col3, #T_c44fa_row1_col4, #T_c44fa_row2_col0, #T_c44fa_row2_col1, #T_c44fa_row2_col2, #T_c44fa_row2_col3, #T_c44fa_row2_col4, #T_c44fa_row3_col0, #T_c44fa_row3_col1, #T_c44fa_row3_col2, #T_c44fa_row3_col3, #T_c44fa_row3_col4, #T_c44fa_row4_col0, #T_c44fa_row4_col1, #T_c44fa_row4_col2, #T_c44fa_row4_col3, #T_c44fa_row4_col4, #T_c44fa_row5_col0, #T_c44fa_row5_col1, #T_c44fa_row5_col2, #T_c44fa_row5_col3, #T_c44fa_row5_col4, #T_c44fa_row6_col0, #T_c44fa_row6_col1, #T_c44fa_row6_col2, #T_c44fa_row6_col3, #T_c44fa_row6_col4, #T_c44fa_row7_col0, #T_c44fa_row7_col1, #T_c44fa_row7_col2, #T_c44fa_row7_col3, #T_c44fa_row7_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_c44fa">
#   <caption>Jenkins Nodes Activity by Labels (weekends)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c44fa_level0_col0" class="col_heading level0 col0" >Labels</th>
#       <th id="T_c44fa_level0_col1" class="col_heading level0 col1" >time_alive</th>
#       <th id="T_c44fa_level0_col2" class="col_heading level0 col2" >busy_time</th>
#       <th id="T_c44fa_level0_col3" class="col_heading level0 col3" >idle_time</th>
#       <th id="T_c44fa_level0_col4" class="col_heading level0 col4" >busy_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c44fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c44fa_row0_col0" class="data row0 col0" >linux-gpu</td>
#       <td id="T_c44fa_row0_col1" class="data row0 col1" >11493.933333</td>
#       <td id="T_c44fa_row0_col2" class="data row0 col2" >3590.750000</td>
#       <td id="T_c44fa_row0_col3" class="data row0 col3" >7903.183333</td>
#       <td id="T_c44fa_row0_col4" class="data row0 col4" >31.240393</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c44fa_row1_col0" class="data row1 col0" >windows-gpu</td>
#       <td id="T_c44fa_row1_col1" class="data row1 col1" >12951.966667</td>
#       <td id="T_c44fa_row1_col2" class="data row1 col2" >1220.816667</td>
#       <td id="T_c44fa_row1_col3" class="data row1 col3" >11731.150000</td>
#       <td id="T_c44fa_row1_col4" class="data row1 col4" >9.425724</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c44fa_row2_col0" class="data row2 col0" >linux</td>
#       <td id="T_c44fa_row2_col1" class="data row2 col1" >11483.916667</td>
#       <td id="T_c44fa_row2_col2" class="data row2 col2" >854.383333</td>
#       <td id="T_c44fa_row2_col3" class="data row2 col3" >10629.533333</td>
#       <td id="T_c44fa_row2_col4" class="data row2 col4" >7.439825</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c44fa_row3_col0" class="data row3 col0" >osx_sonoma</td>
#       <td id="T_c44fa_row3_col1" class="data row3 col1" >12951.966667</td>
#       <td id="T_c44fa_row3_col2" class="data row3 col2" >695.033333</td>
#       <td id="T_c44fa_row3_col3" class="data row3 col3" >12256.933333</td>
#       <td id="T_c44fa_row3_col4" class="data row3 col4" >5.366238</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c44fa_row4_col0" class="data row4 col0" >osx_ventura</td>
#       <td id="T_c44fa_row4_col1" class="data row4 col1" >38855.900000</td>
#       <td id="T_c44fa_row4_col2" class="data row4 col2" >1781.700000</td>
#       <td id="T_c44fa_row4_col3" class="data row4 col3" >37074.200000</td>
#       <td id="T_c44fa_row4_col4" class="data row4 col4" >4.585404</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c44fa_row5_col0" class="data row5 col0" >windows</td>
#       <td id="T_c44fa_row5_col1" class="data row5 col1" >12951.966667</td>
#       <td id="T_c44fa_row5_col2" class="data row5 col2" >302.116667</td>
#       <td id="T_c44fa_row5_col3" class="data row5 col3" >12649.850000</td>
#       <td id="T_c44fa_row5_col4" class="data row5 col4" >2.332593</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c44fa_row6_col0" class="data row6 col0" >core-packages-dfe10fd3, packages, swarm</td>
#       <td id="T_c44fa_row6_col1" class="data row6 col1" >12951.966667</td>
#       <td id="T_c44fa_row6_col2" class="data row6 col2" >19.716667</td>
#       <td id="T_c44fa_row6_col3" class="data row6 col3" >12932.250000</td>
#       <td id="T_c44fa_row6_col4" class="data row6 col4" >0.152229</td>
#     </tr>
#     <tr>
#       <th id="T_c44fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c44fa_row7_col0" class="data row7 col0" >linux-arm64</td>
#       <td id="T_c44fa_row7_col1" class="data row7 col1" >12951.966667</td>
#       <td id="T_c44fa_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c44fa_row7_col3" class="data row7 col3" >12951.966667</td>
#       <td id="T_c44fa_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
